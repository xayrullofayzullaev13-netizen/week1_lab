# %% [markdown]
# <a href="https://colab.research.google.com/github/xayrullofayzullaev13-netizen/week1_lab/blob/main/example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Please update the information, and submit your work

# %%
my_name = "Xayrullo"

# %%
my_enrollment_number = "A85306425068"

# %%
my_hobby = "Skygazing, Reading Books"

# %%
print("Hello, my name is {}, and my my enrollment number is {}. I like {}.".format(my_name, my_enrollment_number, my_hobby))
# Out:
# Hello, my name is John Doe, and my my enrollment number is A123456789. I like Skygazing, Reading Books.
